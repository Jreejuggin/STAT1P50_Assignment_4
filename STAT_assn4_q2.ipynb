# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.datasets import load_diabetes
from tensorflow.keras.layers import Dense, InputLayer
from tensorflow.keras.models import Sequential
import tensorflow as tf
from sklearn.model_selection import train_test_split

diabetes = load_diabetes()
X = diabetes.data
y = diabetes.target

scaler = MinMaxScaler()


y = y.reshape(-1,1)
y = scaler.fit_transform(y)

y = to_categorical(y,3) 


X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3)


model = Sequential()
model2 = Sequential()

input_layer = InputLayer(input_shape=(10,)) # number of neurons/ features
model.add(input_layer)
hidden_layer = Dense(8)
model.add(hidden_layer)

model.add(Dense(3, activation='softmax'))
model.compile(loss='mean_absolute_error')
model.fit(X_train, y_train,epochs=10)

model2.add(Dense(3, activation='relu'))
model2.compile(loss='mean_absolute_error')
model2.fit(X_train, y_train,epochs=10)

print ("2) ‘relu’ activation function be an appropriate for the output layer of this model because the loss numbers are close")
# Out:
# Epoch 1/10
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4379
# Epoch 2/10
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4274
# Epoch 3/10
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4178
# Epoch 4/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4078
# Epoch 5/10
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3972
# Epoch 6/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3859
# Epoch 7/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3739
# Epoch 8/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3612
# Epoch 9/10
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3480
# Epoch 10/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3341
# Epoch 1/10
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3334
# Epoch 2/10
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3269
# ...
