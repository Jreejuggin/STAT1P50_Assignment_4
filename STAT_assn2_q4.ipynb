# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

data = pd.read_csv('student.csv') #reads info in file

data = data[['internet', 'grade']] #only looks at the info in these 2 columns

data2 = data.groupby('internet').mean().reset_index() #finds mean

for bins in [10]:
    plt.hist(data, bins, edgecolor = "black") #creates bar graph
